# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
import sys 
import os


root_path = 'C://Users//HP//projects//DiplomaThesis'
sys.path.append(f'{root_path}')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data import Cleaned, Subset, Meta, Simulated
import figures

# %%
meta = Meta()
meta.load()

# %% [markdown]
# # On not cleaned data

# %%
dt = Subset()
dt.load()

df = dt.features[SORTING]

# %%
figures.plot_missing_observations(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]
# C:\Users\HP\projects\DiplomaThesis\figures.py:60: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   def plot_all_observations(df, xlabel):

# %% [markdown]
# # On cleaned data

# %%
PATHS = {"features":'data/selected/features.pkl', "targets":'data/selected/targets.pkl'}

dt = Cleaned(PATHS)
dt.load()

df = dt.features[figures.SORTING_OLD]
r = dt.targets["r"]

# %%
figures.plot_returns_histogram(r)

# %%
# %matplotlib inline

# %%
figures.plot_histograms(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
figures.plot_correlation_matrix(df)

# %%
figures.plot_correlation_matrix_highest(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
figures.tabulate_most_correlated_pairs(df)
# Out:
#                                                                  Correlation Coefficient
# Max                                        Idiosyncratic Risk                      0.885
# Change in Common Equity                    Net Operating Assets                    0.581
# Lagged Momentum                            Seasonality                             0.474
# 52-Week High                               Idiosyncratic Risk                     -0.385
# Short-Term Reversal                        52-Week High                            0.348
#                                            Max                                     0.344
# Idiosyncratic Risk                         Whited-Wu Index                         0.260
# 52-Week High                               Max                                    -0.256
# Seasonality                                Seasonality 2-5 A                       0.254
# ...

# %%
figures.plot_standard_deviation(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
figures.tabulate_descriptives(df)
# Out:
#                                             Mean     Std     Min     25%  \
# 52-Week High                                -0.0  0.3316 -1.0000 -0.1828
# Short-Term Reversal                         -0.0  0.2430 -0.9831 -0.1276
# Idiosyncratic Risk                          -0.0  0.1999 -0.2929 -0.1204
# Volume Trend                                 0.0  0.2040 -0.8532 -0.0873
# Coefficient of Variation of Share Turnover  -0.0  0.1144 -0.1469 -0.0625
# Max                                          0.0  0.1913 -0.2571 -0.1111
# Whited-Wu Index                              0.0  0.1681 -0.7012 -0.0528
# Coskewness                                  -0.0  0.1996 -1.0000 -0.1014
# Operating Profits to Assets                  0.0  0.0562 -0.3581 -0.0122
# Lagged Momentum                              0.0  0.0316 -0.1518 -0.0053
# Liquidity Beta 5                            -0.0  0.0724 -0.3288 -0.0298
# RD / Market Equity                          -0.0  0.0169 -0.0311 -0.0001
# ...

# %%
figures.tabulate_meta(SORTING_LATEX=figures.SORTING_LATEX_OLD)
# Out:
#                                                      Category    Subcategory  \
# Feature
# 52-Week High                                           Market          Other
# Short-Term Reversal                                    Market          Other
# Idiosyncratic Risk                                     Market          Other
# Volume Trend                                           Market          Other
# Coefficient of Variation of Share Turnover             Market          Other
# Max                                                    Market          Other
# Whited-Wu Index                                    Accounting    Intangibles
# Coskewness                                             Market          Other
# Operating Profits to Assets                        Accounting  Profitability
# Lagged Momentum                                        Market          Other
# Liquidity Beta 5                                       Market          Other
# ...
