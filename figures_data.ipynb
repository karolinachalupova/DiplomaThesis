# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pickle
import sys 
import os


root_path = 'C://Users//HP//projects//DiplomaThesis'
sys.path.append(f'{root_path}')

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from data import Cleaned, Subset, Meta
from figures import SORTING, SORTING_LATEX
import figures

# %%
meta = Meta()
meta.load()

# %% [markdown]
# # On not cleaned data

# %%
dt = Subset()
dt.load()

df = dt.features[SORTING]

# %%
figures.plot_missing_observations(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]
# C:\Users\HP\projects\DiplomaThesis\figures.py:60: UserWarning: Matplotlib is currently using pgf, which is a non-GUI backend, so cannot show the figure.
#   def plot_all_observations(df, xlabel):

# %% [markdown]
# # On cleaned data

# %%
dt = Cleaned()
dt.load()

df = dt.features[SORTING]

# %%
figures.plot_histograms(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
figures.plot_correlation_matrix(df)

# %%
figures.plot_correlation_matrix_highest(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
figures.tabulate_correlation_matrix(df)
# Out:
#                                             52-Week High  Short-Term Reversal  \
# 52-Week High                                       1.000                0.337
# Short-Term Reversal                                0.337                1.000
# Idiosyncratic Risk                                -0.270               -0.011
# Volume / Market Value of Equity                   -0.268               -0.091
# Coefficient of Variation of Share Turnover        -0.136               -0.017
# Max                                               -0.207                0.167
# Whited-Wu Index                                   -0.112               -0.021
# Coskewness                                        -0.004               -0.008
# Operating Profits to Assets                        0.103                0.024
# Lagged Momentum                                    0.325                0.030
# Liquidity Beta 5                                  -0.079               -0.011
# RD / Market Equity                                -0.011               -0.013
# Seasonality 6-10 A                                 0.025                0.025
# Seasonality 11-15 N                                0.056                0.010
# Seasonality 2-5 N                                  0.005                0.005
# Momentum-Reversal                                  0.093                0.018
# Amihud's Measure (Illiquidity)                    -0.159               -0.023
# Net Operating Assets                               0.012                0.001
# Seasonality 6-10 N                                 0.022               -0.005
# Seasonality                                        0.047                0.023
# Seasonality 2-5 A                                  0.036                0.009
# Accruals                                          -0.015               -0.008
# Duration of Equity                                 0.221                0.079
# Change in Common Equity                            0.010                0.006
# Profit Margin                                      0.136                0.033
# Liquidity Beta 3                                   0.068                0.000
# Liquidity Shocks                                   0.030               -0.018
# Leverage Component of Book/Price                  -0.026               -0.004
# Earnings Predictability                            0.064                0.016
# Earnings Forecast-to-Price                         0.132                0.012
#
#                                             Idiosyncratic Risk  \
# 52-Week High                                            -0.270
# Short-Term Reversal                                     -0.011
# Idiosyncratic Risk                                       1.000
# Volume / Market Value of Equity                          0.123
# Coefficient of Variation of Share Turnover               0.162
# Max                                                      0.725
# Whited-Wu Index                                          0.073
# Coskewness                                               0.004
# Operating Profits to Assets                             -0.027
# Lagged Momentum                                         -0.057
# Liquidity Beta 5                                         0.072
# RD / Market Equity                                       0.002
# Seasonality 6-10 A                                      -0.020
# Seasonality 11-15 N                                     -0.055
# Seasonality 2-5 N                                       -0.021
# Momentum-Reversal                                       -0.067
# Amihud's Measure (Illiquidity)                           0.107
# Net Operating Assets                                     0.020
# Seasonality 6-10 N                                      -0.033
# Seasonality                                             -0.020
# Seasonality 2-5 A                                       -0.026
# Accruals                                                 0.009
# Duration of Equity                                      -0.045
# Change in Common Equity                                  0.029
# Profit Margin                                           -0.090
# Liquidity Beta 3                                        -0.048
# Liquidity Shocks                                        -0.040
# Leverage Component of Book/Price                         0.017
# Earnings Predictability                                 -0.069
# Earnings Forecast-to-Price                              -0.110
#
#                                             Volume / Market Value of Equity  \
# 52-Week High                                                         -0.268
# Short-Term Reversal                                                  -0.091
# Idiosyncratic Risk                                                    0.123
# Volume / Market Value of Equity                                       1.000
# Coefficient of Variation of Share Turnover                            0.004
# Max                                                                   0.117
# Whited-Wu Index                                                      -0.065
# Coskewness                                                            0.006
# Operating Profits to Assets                                           0.062
# Lagged Momentum                                                      -0.004
# Liquidity Beta 5                                                      0.202
# RD / Market Equity                                                    0.083
# Seasonality 6-10 A                                                    0.009
# Seasonality 11-15 N                                                   0.018
# Seasonality 2-5 N                                                     0.097
# Momentum-Reversal                                                     0.014
# Amihud's Measure (Illiquidity)                                       -0.155
# Net Operating Assets                                                  0.047
# Seasonality 6-10 N                                                    0.038
# Seasonality                                                           0.025
# Seasonality 2-5 A                                                     0.010
# Accruals                                                             -0.025
# Duration of Equity                                                    0.015
# Change in Common Equity                                               0.041
# Profit Margin                                                         0.001
# Liquidity Beta 3                                                     -0.154
# Liquidity Shocks                                                      0.048
# Leverage Component of Book/Price                                      0.008
# Earnings Predictability                                              -0.013
# Earnings Forecast-to-Price                                            0.103
#
#                                             Coefficient of Variation of Share Turnover  \
# 52-Week High                                                                    -0.136
# Short-Term Reversal                                                             -0.017
# Idiosyncratic Risk                                                               0.162
# Volume / Market Value of Equity                                                  0.004
# Coefficient of Variation of Share Turnover                                       1.000
# Max                                                                              0.130
# Whited-Wu Index                                                                  0.119
# Coskewness                                                                      -0.011
# Operating Profits to Assets                                                     -0.099
# Lagged Momentum                                                                 -0.052
# Liquidity Beta 5                                                                 0.037
# RD / Market Equity                                                              -0.057
# Seasonality 6-10 A                                                              -0.035
# Seasonality 11-15 N                                                             -0.062
# Seasonality 2-5 N                                                               -0.050
# Momentum-Reversal                                                               -0.058
# Amihud's Measure (Illiquidity)                                                   0.332
# Net Operating Assets                                                             0.011
# Seasonality 6-10 N                                                              -0.043
# Seasonality                                                                     -0.041
# Seasonality 2-5 A                                                               -0.040
# Accruals                                                                         0.011
# Duration of Equity                                                              -0.100
# Change in Common Equity                                                         -0.016
# Profit Margin                                                                   -0.056
# Liquidity Beta 3                                                                -0.058
# Liquidity Shocks                                                                -0.146
# Leverage Component of Book/Price                                                 0.005
# Earnings Predictability                                                         -0.056
# Earnings Forecast-to-Price                                                      -0.105
#
#                                               Max  Whited-Wu Index  \
# 52-Week High                               -0.207           -0.112
# Short-Term Reversal                         0.167           -0.021
# Idiosyncratic Risk                          0.725            0.073
# Volume / Market Value of Equity             0.117           -0.065
# Coefficient of Variation of Share Turnover  0.130            0.119
# Max                                         1.000            0.065
# Whited-Wu Index                             0.065            1.000
# Coskewness                                  0.004            0.009
# Operating Profits to Assets                -0.030           -0.303
# Lagged Momentum                            -0.054           -0.035
# Liquidity Beta 5                            0.080           -0.153
# RD / Market Equity                          0.006           -0.175
# Seasonality 6-10 A                         -0.012           -0.054
# Seasonality 11-15 N                        -0.039           -0.139
# Seasonality 2-5 N                          -0.022           -0.046
# Momentum-Reversal                          -0.064           -0.040
# Amihud's Measure (Illiquidity)              0.102            0.212
# Net Operating Assets                        0.006           -0.433
# Seasonality 6-10 N                         -0.027           -0.116
# Seasonality                                -0.016           -0.056
# Seasonality 2-5 A                          -0.024           -0.044
# Accruals                                    0.009            0.129
# Duration of Equity                         -0.024           -0.006
# Change in Common Equity                     0.017           -0.099
# Profit Margin                              -0.082           -0.193
# Liquidity Beta 3                           -0.059            0.023
# Liquidity Shocks                           -0.055           -0.110
# Leverage Component of Book/Price            0.009            0.010
# Earnings Predictability                    -0.055           -0.079
# Earnings Forecast-to-Price                 -0.103           -0.167
#
#                                             Coskewness  \
# 52-Week High                                    -0.004
# Short-Term Reversal                             -0.008
# Idiosyncratic Risk                               0.004
# Volume / Market Value of Equity                  0.006
# Coefficient of Variation of Share Turnover      -0.011
# Max                                              0.004
# Whited-Wu Index                                  0.009
# Coskewness                                       1.000
# Operating Profits to Assets                     -0.013
# Lagged Momentum                                 -0.021
# Liquidity Beta 5                                 0.053
# RD / Market Equity                              -0.001
# Seasonality 6-10 A                              -0.016
# Seasonality 11-15 N                             -0.016
# Seasonality 2-5 N                               -0.044
# Momentum-Reversal                               -0.030
# Amihud's Measure (Illiquidity)                  -0.035
# Net Operating Assets                            -0.045
# Seasonality 6-10 N                              -0.065
# Seasonality                                     -0.018
# Seasonality 2-5 A                               -0.016
# Accruals                                         0.017
# Duration of Equity                              -0.005
# Change in Common Equity                         -0.015
# Profit Margin                                   -0.002
# Liquidity Beta 3                                 0.062
# Liquidity Shocks                                 0.016
# Leverage Component of Book/Price                -0.008
# Earnings Predictability                         -0.023
# Earnings Forecast-to-Price                      -0.045
#
#                                             Operating Profits to Assets  \
# 52-Week High                                                      0.103
# Short-Term Reversal                                               0.024
# Idiosyncratic Risk                                               -0.027
# Volume / Market Value of Equity                                   0.062
# Coefficient of Variation of Share Turnover                       -0.099
# Max                                                              -0.030
# Whited-Wu Index                                                  -0.303
# Coskewness                                                       -0.013
# Operating Profits to Assets                                       1.000
# Lagged Momentum                                                   0.050
# Liquidity Beta 5                                                  0.006
# RD / Market Equity                                                0.277
# Seasonality 6-10 A                                                0.032
# Seasonality 11-15 N                                               0.063
# Seasonality 2-5 N                                                 0.104
# Momentum-Reversal                                                 0.069
# Amihud's Measure (Illiquidity)                                   -0.172
# Net Operating Assets                                              0.225
# Seasonality 6-10 N                                                0.066
# Seasonality                                                       0.043
# Seasonality 2-5 A                                                 0.046
# Accruals                                                         -0.083
# Duration of Equity                                                0.186
# Change in Common Equity                                           0.183
# Profit Margin                                                     0.238
# Liquidity Beta 3                                                  0.058
# Liquidity Shocks                                                  0.079
# Leverage Component of Book/Price                                 -0.002
# Earnings Predictability                                           0.005
# Earnings Forecast-to-Price                                        0.144
#
#                                             Lagged Momentum  ...  \
# 52-Week High                                          0.325  ...
# Short-Term Reversal                                   0.030  ...
# Idiosyncratic Risk                                   -0.057  ...
# Volume / Market Value of Equity                      -0.004  ...
# Coefficient of Variation of Share Turnover           -0.052  ...
# Max                                                  -0.054  ...
# Whited-Wu Index                                      -0.035  ...
# Coskewness                                           -0.021  ...
# Operating Profits to Assets                           0.050  ...
# Lagged Momentum                                       1.000  ...
# Liquidity Beta 5                                     -0.000  ...
# RD / Market Equity                                   -0.026  ...
# Seasonality 6-10 A                                    0.013  ...
# Seasonality 11-15 N                                   0.011  ...
# Seasonality 2-5 N                                     0.002  ...
# Momentum-Reversal                                     0.014  ...
# Amihud's Measure (Illiquidity)                       -0.089  ...
# Net Operating Assets                                  0.012  ...
# Seasonality 6-10 N                                   -0.005  ...
# Seasonality                                           0.121  ...
# Seasonality 2-5 A                                     0.001  ...
# Accruals                                             -0.020  ...
# Duration of Equity                                    0.157  ...
# Change in Common Equity                               0.043  ...
# Profit Margin                                         0.060  ...
# Liquidity Beta 3                                     -0.021  ...
# Liquidity Shocks                                      0.023  ...
# Leverage Component of Book/Price                     -0.008  ...
# Earnings Predictability                               0.030  ...
# Earnings Forecast-to-Price                            0.084  ...
#
#                                             Seasonality 2-5 A  Accruals  \
# 52-Week High                                            0.036    -0.015
# Short-Term Reversal                                     0.009    -0.008
# Idiosyncratic Risk                                     -0.026     0.009
# Volume / Market Value of Equity                         0.010    -0.025
# Coefficient of Variation of Share Turnover             -0.040     0.011
# Max                                                    -0.024     0.009
# Whited-Wu Index                                        -0.044     0.129
# Coskewness                                             -0.016     0.017
# Operating Profits to Assets                             0.046    -0.083
# Lagged Momentum                                         0.001    -0.020
# Liquidity Beta 5                                        0.006    -0.027
# RD / Market Equity                                     -0.005    -0.075
# Seasonality 6-10 A                                      0.041    -0.008
# Seasonality 11-15 N                                     0.002    -0.026
# Seasonality 2-5 N                                      -0.017     0.027
# Momentum-Reversal                                       0.024    -0.004
# Amihud's Measure (Illiquidity)                         -0.060    -0.014
# Net Operating Assets                                    0.033    -0.043
# Seasonality 6-10 N                                      0.002    -0.020
# Seasonality                                             0.527    -0.003
# Seasonality 2-5 A                                       1.000     0.009
# Accruals                                                0.009     1.000
# Duration of Equity                                      0.047    -0.075
# Change in Common Equity                                 0.056     0.120
# Profit Margin                                           0.050    -0.009
# Liquidity Beta 3                                       -0.005     0.037
# Liquidity Shocks                                        0.031     0.018
# Leverage Component of Book/Price                        0.002     0.019
# Earnings Predictability                                 0.017    -0.056
# Earnings Forecast-to-Price                              0.053    -0.007
#
#                                             Duration of Equity  \
# 52-Week High                                             0.221
# Short-Term Reversal                                      0.079
# Idiosyncratic Risk                                      -0.045
# Volume / Market Value of Equity                          0.015
# Coefficient of Variation of Share Turnover              -0.100
# Max                                                     -0.024
# Whited-Wu Index                                         -0.006
# Coskewness                                              -0.005
# Operating Profits to Assets                              0.186
# Lagged Momentum                                          0.157
# Liquidity Beta 5                                        -0.046
# RD / Market Equity                                       0.008
# Seasonality 6-10 A                                       0.025
# Seasonality 11-15 N                                      0.038
# Seasonality 2-5 N                                        0.169
# Momentum-Reversal                                        0.121
# Amihud's Measure (Illiquidity)                          -0.166
# Net Operating Assets                                    -0.022
# Seasonality 6-10 N                                       0.062
# Seasonality                                              0.058
# Seasonality 2-5 A                                        0.047
# Accruals                                                -0.075
# Duration of Equity                                       1.000
# Change in Common Equity                                  0.042
# Profit Margin                                            0.029
# Liquidity Beta 3                                         0.040
# Liquidity Shocks                                         0.040
# Leverage Component of Book/Price                        -0.178
# Earnings Predictability                                  0.054
# Earnings Forecast-to-Price                               0.051
#
#                                             Change in Common Equity  \
# 52-Week High                                                  0.010
# Short-Term Reversal                                           0.006
# Idiosyncratic Risk                                            0.029
# Volume / Market Value of Equity                               0.041
# Coefficient of Variation of Share Turnover                   -0.016
# Max                                                           0.017
# Whited-Wu Index                                              -0.099
# Coskewness                                                   -0.015
# Operating Profits to Assets                                   0.183
# Lagged Momentum                                               0.043
# Liquidity Beta 5                                             -0.052
# RD / Market Equity                                           -0.046
# Seasonality 6-10 A                                            0.001
# Seasonality 11-15 N                                          -0.040
# Seasonality 2-5 N                                             0.202
# Momentum-Reversal                                             0.110
# Amihud's Measure (Illiquidity)                               -0.108
# Net Operating Assets                                          0.301
# Seasonality 6-10 N                                            0.018
# Seasonality                                                   0.039
# Seasonality 2-5 A                                             0.056
# Accruals                                                      0.120
# Duration of Equity                                            0.042
# Change in Common Equity                                       1.000
# Profit Margin                                                 0.188
# Liquidity Beta 3                                              0.039
# Liquidity Shocks                                              0.063
# Leverage Component of Book/Price                              0.075
# Earnings Predictability                                      -0.025
# Earnings Forecast-to-Price                                    0.109
#
#                                             Profit Margin  Liquidity Beta 3  \
# 52-Week High                                        0.136             0.068
# Short-Term Reversal                                 0.033             0.000
# Idiosyncratic Risk                                 -0.090            -0.048
# Volume / Market Value of Equity                     0.001            -0.154
# Coefficient of Variation of Share Turnover         -0.056            -0.058
# Max                                                -0.082            -0.059
# Whited-Wu Index                                    -0.193             0.023
# Coskewness                                         -0.002             0.062
# Operating Profits to Assets                         0.238             0.058
# Lagged Momentum                                     0.060            -0.021
# Liquidity Beta 5                                    0.017            -0.435
# RD / Market Equity                                  0.006            -0.031
# Seasonality 6-10 A                                  0.025            -0.004
# Seasonality 11-15 N                                 0.030            -0.021
# Seasonality 2-5 N                                   0.096            -0.073
# Momentum-Reversal                                   0.077            -0.017
# Amihud's Measure (Illiquidity)                     -0.129            -0.031
# Net Operating Assets                                0.178            -0.016
# Seasonality 6-10 N                                  0.049            -0.053
# Seasonality                                         0.044            -0.019
# Seasonality 2-5 A                                   0.050            -0.005
# Accruals                                           -0.009             0.037
# Duration of Equity                                  0.029             0.040
# Change in Common Equity                             0.188             0.039
# Profit Margin                                       1.000             0.007
# Liquidity Beta 3                                    0.007             1.000
# Liquidity Shocks                                    0.071             0.024
# Leverage Component of Book/Price                    0.017            -0.022
# Earnings Predictability                            -0.004            -0.099
# Earnings Forecast-to-Price                          0.218            -0.058
#
#                                             Liquidity Shocks  \
# 52-Week High                                           0.030
# Short-Term Reversal                                   -0.018
# Idiosyncratic Risk                                    -0.040
# Volume / Market Value of Equity                        0.048
# Coefficient of Variation of Share Turnover            -0.146
# Max                                                   -0.055
# Whited-Wu Index                                       -0.110
# Coskewness                                             0.016
# Operating Profits to Assets                            0.079
# Lagged Momentum                                        0.023
# Liquidity Beta 5                                       0.013
# RD / Market Equity                                     0.042
# Seasonality 6-10 A                                     0.021
# Seasonality 11-15 N                                    0.024
# Seasonality 2-5 N                                      0.078
# Momentum-Reversal                                      0.066
# Amihud's Measure (Illiquidity)                        -0.520
# Net Operating Assets                                   0.038
# Seasonality 6-10 N                                     0.039
# Seasonality                                            0.030
# Seasonality 2-5 A                                      0.031
# Accruals                                               0.018
# Duration of Equity                                     0.040
# Change in Common Equity                                0.063
# Profit Margin                                          0.071
# Liquidity Beta 3                                       0.024
# Liquidity Shocks                                       1.000
# Leverage Component of Book/Price                       0.002
# Earnings Predictability                                0.028
# Earnings Forecast-to-Price                             0.066
#
#                                             Leverage Component of Book/Price  \
# 52-Week High                                                          -0.026
# Short-Term Reversal                                                   -0.004
# Idiosyncratic Risk                                                     0.017
# Volume / Market Value of Equity                                        0.008
# Coefficient of Variation of Share Turnover                             0.005
# Max                                                                    0.009
# Whited-Wu Index                                                        0.010
# Coskewness                                                            -0.008
# Operating Profits to Assets                                           -0.002
# Lagged Momentum                                                       -0.008
# Liquidity Beta 5                                                      -0.009
# RD / Market Equity                                                    -0.027
# Seasonality 6-10 A                                                    -0.007
# Seasonality 11-15 N                                                   -0.022
# Seasonality 2-5 N                                                      0.004
# Momentum-Reversal                                                     -0.002
# Amihud's Measure (Illiquidity)                                         0.016
# Net Operating Assets                                                  -0.067
# Seasonality 6-10 N                                                    -0.029
# Seasonality                                                           -0.003
# Seasonality 2-5 A                                                      0.002
# Accruals                                                               0.019
# Duration of Equity                                                    -0.178
# Change in Common Equity                                                0.075
# Profit Margin                                                          0.017
# Liquidity Beta 3                                                      -0.022
# Liquidity Shocks                                                       0.002
# Leverage Component of Book/Price                                       1.000
# Earnings Predictability                                               -0.006
# Earnings Forecast-to-Price                                             0.025
#
#                                             Earnings Predictability  \
# 52-Week High                                                  0.064
# Short-Term Reversal                                           0.016
# Idiosyncratic Risk                                           -0.069
# Volume / Market Value of Equity                              -0.013
# Coefficient of Variation of Share Turnover                   -0.056
# Max                                                          -0.055
# Whited-Wu Index                                              -0.079
# Coskewness                                                   -0.023
# Operating Profits to Assets                                   0.005
# Lagged Momentum                                               0.030
# Liquidity Beta 5                                              0.027
# RD / Market Equity                                            0.030
# Seasonality 6-10 A                                            0.034
# Seasonality 11-15 N                                           0.113
# Seasonality 2-5 N                                             0.025
# Momentum-Reversal                                             0.026
# Amihud's Measure (Illiquidity)                               -0.048
# Net Operating Assets                                         -0.026
# Seasonality 6-10 N                                            0.065
# Seasonality                                                   0.024
# Seasonality 2-5 A                                             0.017
# Accruals                                                     -0.056
# Duration of Equity                                            0.054
# Change in Common Equity                                      -0.025
# Profit Margin                                                -0.004
# Liquidity Beta 3                                             -0.099
# Liquidity Shocks                                              0.028
# Leverage Component of Book/Price                             -0.006
# Earnings Predictability                                       1.000
# Earnings Forecast-to-Price                                    0.059
#
#                                             Earnings Forecast-to-Price
# 52-Week High                                                     0.132
# Short-Term Reversal                                              0.012
# Idiosyncratic Risk                                              -0.110
# Volume / Market Value of Equity                                  0.103
# Coefficient of Variation of Share Turnover                      -0.105
# Max                                                             -0.103
# Whited-Wu Index                                                 -0.167
# Coskewness                                                      -0.045
# Operating Profits to Assets                                      0.144
# Lagged Momentum                                                  0.084
# Liquidity Beta 5                                                 0.047
# RD / Market Equity                                              -0.023
# Seasonality 6-10 A                                               0.032
# Seasonality 11-15 N                                              0.045
# Seasonality 2-5 N                                                0.136
# Momentum-Reversal                                                0.100
# Amihud's Measure (Illiquidity)                                  -0.150
# Net Operating Assets                                             0.091
# Seasonality 6-10 N                                               0.064
# Seasonality                                                      0.050
# Seasonality 2-5 A                                                0.053
# Accruals                                                        -0.007
# Duration of Equity                                               0.051
# Change in Common Equity                                          0.109
# Profit Margin                                                    0.218
# Liquidity Beta 3                                                -0.058
# Liquidity Shocks                                                 0.066
# Leverage Component of Book/Price                                 0.025
# Earnings Predictability                                          0.059
# Earnings Forecast-to-Price                                       1.000
#
# [30 rows x 30 columns]

# %%
figures.tabulate_most_correlated_pairs(df)
# Out:
# Idiosyncratic Risk                          Max                                           0.724558
# Seasonality                                 Seasonality 2-5 A                             0.527391
# Amihud's Measure (Illiquidity)              Liquidity Shocks                             -0.520260
# Liquidity Beta 3                            Liquidity Beta 5                             -0.435306
# Whited-Wu Index                             Net Operating Assets                         -0.432899
# Seasonality 6-10 A                          Seasonality                                   0.401306
# 52-Week High                                Short-Term Reversal                           0.336991
# Coefficient of Variation of Share Turnover  Amihud's Measure (Illiquidity)                0.332328
# Lagged Momentum                             52-Week High                                  0.324630
# Momentum-Reversal                           Seasonality 2-5 N                             0.304061
# 52-Week High                                Idiosyncratic Risk                           -0.270466
# Amihud's Measure (Illiquidity)              Whited-Wu Index                               0.212470
# Max                                         52-Week High                                 -0.207491
# Short-Term Reversal                         Max                                           0.166682
# Idiosyncratic Risk                          Coefficient of Variation of Share Turnover    0.162290
# dtype: float64

# %%
figures.plot_standard_deviation(df)
# Out:
# C:\Users\HP\Anaconda3\Lib\_collections_abc.py:841: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   self[key] = other[key]

# %%
figures.tabulate_descriptives(df)
# Out:
#                                             Mean     Std     Min     25%  \
# 52-Week High                                 0.0  0.3071 -1.0000 -0.1126
# Short-Term Reversal                         -0.0  0.3704 -1.0000 -0.2174
# Idiosyncratic Risk                           0.0  0.4403 -0.9752 -0.3038
# Volume / Market Value of Equity             -0.0  0.3747 -0.4584 -0.2709
# Coefficient of Variation of Share Turnover   0.0  0.4436 -0.8373 -0.2992
# Max                                         -0.0  0.4146 -0.7492 -0.2925
# Whited-Wu Index                              0.0  0.5424 -1.0000 -0.4148
# Coskewness                                   0.0  0.4030 -1.0000 -0.2443
# Operating Profits to Assets                  0.0  0.3769 -1.0000 -0.2765
# Lagged Momentum                              0.0  0.4027 -1.0000 -0.2511
# Liquidity Beta 5                            -0.0  0.5324 -1.0000 -0.3462
# RD / Market Equity                          -0.0  0.3173 -0.1806 -0.1693
# Seasonality 6-10 A                           0.0  0.3523 -1.0000 -0.1447
# Seasonality 11-15 N                         -0.0  0.3759 -1.0000 -0.2122
# Seasonality 2-5 N                            0.0  0.3515 -1.0000 -0.2002
# Momentum-Reversal                            0.0  0.4057 -1.0000 -0.2458
# Amihud's Measure (Illiquidity)              -0.0  0.2697 -0.1343 -0.1042
# Net Operating Assets                         0.0  0.5027 -1.0000 -0.4207
# Seasonality 6-10 N                           0.0  0.3689 -1.0000 -0.2252
# Seasonality                                 -0.0  0.3361 -1.0000 -0.1740
# Seasonality 2-5 A                           -0.0  0.3671 -1.0000 -0.2022
# Accruals                                     0.0  0.2727 -1.0000 -0.1180
# Duration of Equity                           0.0  0.2035 -1.0000 -0.0673
# Change in Common Equity                     -0.0  0.3025 -1.0000 -0.1405
# Profit Margin                               -0.0  0.1888 -1.0000 -0.0138
# Liquidity Beta 3                            -0.0  0.3286 -1.0000 -0.1563
# Liquidity Shocks                            -0.0  0.1244 -1.0000  0.0158
# Leverage Component of Book/Price             0.0  0.1766 -1.0000 -0.0197
# Earnings Predictability                     -0.0  0.2439 -0.0900 -0.0752
# Earnings Forecast-to-Price                   0.0  0.3024 -1.0000 -0.1921
#
#                                                50%     75%     Max
# 52-Week High                                0.0765  0.1971  0.5366
# Short-Term Reversal                        -0.0023  0.2225  0.8637
# Idiosyncratic Risk                         -0.0835  0.2437  1.0000
# Volume / Market Value of Equity            -0.1219  0.1537  1.0000
# Coefficient of Variation of Share Turnover -0.0924  0.2506  1.0000
# Max                                        -0.0982  0.2085  1.0000
# Whited-Wu Index                            -0.1142  0.4541  1.0000
# Coskewness                                  0.0486  0.2453  0.8649
# Operating Profits to Assets                -0.1101  0.2248  1.0000
# Lagged Momentum                            -0.0200  0.2385  1.0000
# Liquidity Beta 5                           -0.0257  0.3874  1.0000
# RD / Market Equity                         -0.1285 -0.0438  1.0000
# Seasonality 6-10 A                         -0.0287  0.1860  0.8851
# Seasonality 11-15 N                        -0.0921  0.2069  1.0000
# Seasonality 2-5 N                          -0.0198  0.2066  0.8949
# Momentum-Reversal                          -0.0211  0.2385  1.0000
# Amihud's Measure (Illiquidity)             -0.0923 -0.0689  1.0000
# Net Operating Assets                        0.0598  0.3546  1.0000
# Seasonality 6-10 N                         -0.0502  0.2213  1.0000
# Seasonality                                -0.0120  0.1990  0.7349
# Seasonality 2-5 A                          -0.0122  0.2224  0.8339
# Accruals                                    0.0590  0.1406  0.5606
# Duration of Equity                          0.0419  0.1293  0.3104
# Change in Common Equity                    -0.0406  0.0960  1.0000
# Profit Margin                               0.0150  0.0378  1.0000
# Liquidity Beta 3                            0.0863  0.1952  0.6684
# Liquidity Shocks                            0.0201  0.0229  0.3647
# Leverage Component of Book/Price            0.0064  0.0499  0.6213
# Earnings Predictability                    -0.0701 -0.0608  1.0000
# Earnings Forecast-to-Price                 -0.0080  0.1614  1.0000

# %%
figures.tabulate_meta()
# Out:
#                                                      Category    Subcategory  \
#
# 52-Week High                                           Market          Other
# Short-Term Reversal                                    Market          Other
# Idiosyncratic Risk                                     Market          Other
# Volume / Market Value of Equity                        Market          Other
# Coefficient of Variation of Share Turnover             Market          Other
# Max                                                    Market          Other
# Whited-Wu Index                                    Accounting    Intangibles
# Coskewness                                             Market          Other
# Operating Profits to Assets                        Accounting  Profitability
# Lagged Momentum                                        Market          Other
# Liquidity Beta 5                                       Market          Other
# RD / Market Equity                                 Accounting    Intangibles
# Seasonality 6-10 A                                     Market          Other
# Seasonality 11-15 N                                    Market          Other
# Seasonality 2-5 N                                      Market          Other
# Momentum-Reversal                                      Market          Other
# Amihud's Measure (Illiquidity)                         Market          Other
# Net Operating Assets                               Accounting     Investment
# Seasonality 6-10 N                                     Market          Other
# Seasonality                                            Market          Other
# Seasonality 2-5 A                                      Market          Other
# Accruals                                           Accounting       Accruals
# Duration of Equity                                 Accounting          Value
# Change in Common Equity                            Accounting       Accruals
# Profit Margin                                      Accounting  Profitability
# Liquidity Beta 3                                       Market          Other
# Liquidity Shocks                                       Market          Other
# Leverage Component of Book/Price                   Accounting          Value
# Earnings Predictability                            Accounting    Intangibles
# Earnings Forecast-to-Price                  Analyst Forecasts          Other
#
#                                                                        Author  \
#
# 52-Week High                                              \cite{george200452}
# Short-Term Reversal                              \cite{jegadeesh1990evidence}
# Idiosyncratic Risk                                        \cite{ang2006cross}
# Volume / Market Value of Equity                  \cite{haugen1996commonality}
# Coefficient of Variation of Share Turnover          \cite{chordia2001trading}
# Max                                                     \cite{bali2011maxing}
# Whited-Wu Index                                    \cite{whited2006financial}
# Coskewness                                       \cite{harvey2000conditional}
# Operating Profits to Assets                           \cite{ball2016accruals}
# Lagged Momentum                                       \cite{novy2012momentum}
# Liquidity Beta 5                                      \cite{acharya2005asset}
# RD / Market Equity                                       \cite{chan2001stock}
# Seasonality 6-10 A                               \cite{heston2008seasonality}
# Seasonality 11-15 N                              \cite{heston2008seasonality}
# Seasonality 2-5 N                                \cite{heston2008seasonality}
# Momentum-Reversal                                 \cite{jegadeesh1993returns}
# Amihud's Measure (Illiquidity)                   \cite{amihud2002illiquidity}
# Net Operating Assets                          \cite{hirshleifer2004investors}
# Seasonality 6-10 N                               \cite{heston2008seasonality}
# Seasonality                                      \cite{heston2008seasonality}
# Seasonality 2-5 A                                \cite{heston2008seasonality}
# Accruals                                               \cite{sloan1996create}
# Duration of Equity                                   \cite{dechow2004implied}
# Change in Common Equity                     \cite{richardson2006implications}
# Profit Margin                                           \cite{soliman2008use}
# Liquidity Beta 3                                      \cite{acharya2005asset}
# Liquidity Shocks                                     \cite{bali2013liquidity}
# Leverage Component of Book/Price                        \cite{penman2007book}
# Earnings Predictability                               \cite{francis2004costs}
# Earnings Forecast-to-Price                           \cite{elgers2001delayed}
#
#                                            Journal Frequency
#
# 52-Week High                                    JF         M
# Short-Term Reversal                             JF         M
# Idiosyncratic Risk                              JF         M
# Volume / Market Value of Equity                JFE         M
# Coefficient of Variation of Share Turnover     JFE         M
# Max                                             JF         M
# Whited-Wu Index                                RFS         M
# Coskewness                                      JF         M
# Operating Profits to Assets                    JFE         Y
# Lagged Momentum                                JFE         M
# Liquidity Beta 5                               JFE         M
# RD / Market Equity                              JF         Y
# Seasonality 6-10 A                             JFE         M
# Seasonality 11-15 N                            JFE         M
# Seasonality 2-5 N                              JFE         M
# Momentum-Reversal                               JF         M
# Amihud's Measure (Illiquidity)                 JFM         M
# Net Operating Assets                           JAE         M
# Seasonality 6-10 N                             JFE         M
# Seasonality                                    JFE         M
# Seasonality 2-5 A                              JFE         M
# Accruals                                        AR         Y
# Duration of Equity                             RAS         Y
# Change in Common Equity                         AR         Y
# Profit Margin                                   AR         Y
# Liquidity Beta 3                               JFE         M
# Liquidity Shocks                               RFS         M
# Leverage Component of Book/Price               JAR         Y
# Earnings Predictability                         AR         Y
# Earnings Forecast-to-Price                      AR         M
